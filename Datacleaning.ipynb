# %% [markdown]
# ## GROW
#
#
# ## descrizione campi:
#
# numcard: number of fidelity cardvowned
#
# mycard: if owns our fidelity card
#
# weeklypurch: number of purchases per week
#
# wepurch: percentage of purchases during we

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_44174814cdbe4f79bbb72d521543f266 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='ji6PmLvZ0FFwTlr7jx6eINkE6eLjvStsxG3TdAUyaITX',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')

body = client_44174814cdbe4f79bbb72d521543f266.get_object(Bucket='grow-donotdelete-pr-bvat7k23bphyr6',Key='input.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()

# %% [markdown]
# ## Load and explore Data

# %%
print("the table contains these raws, columns",df_data_2.shape)
df_data_2.describe()

# %%
df_data_2.info()

# %%
#number of nulls for each feature
null_columns=df_data_2.columns[df_data_2.isnull().any()]
df_data_2.isnull().sum()

# %%
#Correlation matrix of features
import matplotlib.pyplot as plt
import seaborn as sns
corr=df_data_2.corr()
plt.figure(figsize=(10, 10))

sns.heatmap(corr, vmax=.8, linewidths=0.01,
            square=True,annot=True,cmap='YlGnBu',linecolor="white")
plt.title('Correlation between features');

# %% [markdown]
# ## gestiamo i valori nulli

# %%
#colonne nulle
df_data_2[df_data_2['weeklypurch'].isnull()]

# %% [markdown]
# We can substitute the null value with the column average

# %%
#
df_data_2.describe()

# %%
#number of nulls for each feature
null_columns=df_data_2.columns[df_data_2.isnull().any()]
df_data_2.isnull().sum()

# %%
df_data_2=df_data_2.fillna(df_data_2.mean())

# %%
#number of nulls for each feature
null_columns=df_data_2.columns[df_data_2.isnull().any()]
df_data_2.isnull().sum()

# %%
#
df_data_2.describe()

# %%
df_data_2['weeklypurch'] = df_data_2['weeklypurch'].mask(df_data_2['weeklypurch'] > 200, 49)

# %%
df_data_2['weeklypurch'] = df_data_2['weeklypurch'].mask(df_data_2['weeklypurch'] < 0, 49)

# %%
#
df_data_2.head(10)
